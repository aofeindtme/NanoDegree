# %%
# imports and load data
import pandas as pd
# %matplotlib inline

df=pd.read_csv("store_data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
# week      200 non-null object
# storeA    200 non-null int64
# storeB    200 non-null int64
# storeC    200 non-null int64
# storeD    200 non-null int64
# storeE    200 non-null int64
# dtypes: int64(5), object(1)
# memory usage: 9.5+ KB

# %%
df.dtypes
# Out:
# week      object
# storeA     int64
# storeB     int64
# storeC     int64
# storeD     int64
# storeE     int64
# dtype: object

# %%
# explore data
df['storeA'].hist();

# %%
df.hist(figsize=(8,8));

# %%
df['storeA'].hist();

# %%
df['storeA'].plot(kind='hist');

# %%
df['storeA'].value_counts()
# Out:
# 5310     2
# 4704     2
# 4853     2
# 6282     2
# 5190     1
# 3936     1
# 5719     1
# 1366     1
# 8532     1
# 2643     1
# 4178     1
# 3409     1
# 5712     1
# 335      1
# 1100     1
# 9051     1
# 8267     1
# 7242     1
# 2377     1
# 5960     1
# 6727     1
# 2899     1
# 4191     1
# 14403    1
# 8890     1
# 2648     1
# 6237     1
# 6835     1
# 4715     1
# 8567     1
#         ..
# 5506     1
# 1921     1
# 8976     1
# 11646    1
# 7293     1
# 10685    1
# 7629     1
# 10432    1
# 5553     1
# 9202     1
# 2749     1
# 10683    1
# 6586     1
# 8556     1
# 8120     1
# 7607     1
# 5299     1
# 2226     1
# 3810     1
# 10400    1
# 9646     1
# 5292     1
# 5803     1
# 3240     1
# 6393     1
# 5715     1
# 5795     1
# 4514     1
# 7329     1
# 282      1
# Name: storeA, Length: 196, dtype: int64

# %%
df.plot(kind='box');

# %%
# sales for the last month

# %%
# average sales

# %%
# sales for the week of March 13th, 2016

# %%
# share of sales for the latest 3-month periods
